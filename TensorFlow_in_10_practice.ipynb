# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnsonManuel/Learning-AI/blob/main/TensorFlow_in_10_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Churn.csv')

# %%
X = pd.get_dummies(df.drop(['Churn','Customer ID'] ,axis = 1))

# %%
Y = df['Churn'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.head()
# Out:
#       Senior Citizen  tenure  Monthly Charges  Gender_Female  Gender_Male  \
# 5371               0      16            90.80              0            1
# 6815               1      57            94.00              1            0
# 2371               0      69           112.55              0            1
# 4302               0      66            19.75              0            1
# 6096               0       4            19.65              0            1
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 5371           0            1              0               1
# 6815           0            1              1               0
# 2371           0            1              1               0
# 4302           0            1              0               1
# 6096           1            0              1               0
#
#       Phone Service_No  ...  Total Charges_995.35  Total Charges_996.45  \
# 5371                 0  ...                     0                     0
# ...

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics='accuracy')

# %%
model.fit(X_train, y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.5015 - accuracy: 0.7633
# Epoch 2/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4849 - accuracy: 0.7688
# Epoch 3/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4790 - accuracy: 0.7769
# Epoch 4/200
# 177/177 [==============================] - 1s 6ms/step - loss: 0.4769 - accuracy: 0.7815
# Epoch 5/200
# 177/177 [==============================] - 1s 6ms/step - loss: 0.4726 - accuracy: 0.7833
# Epoch 6/200
# 177/177 [==============================] - 1s 7ms/step - loss: 0.4675 - accuracy: 0.7826
# Epoch 7/200
# 177/177 [==============================] - 1s 6ms/step - loss: 0.4613 - accuracy: 0.7828
# Epoch 8/200
# 177/177 [==============================] - 1s 5ms/step - loss: 0.4643 - accuracy: 0.7839
# Epoch 9/200
# 177/177 [==============================] - 1s 4ms/step - loss: 0.4598 - accuracy: 0.7902
# Epoch 10/200
# ...

# %%
y_hat = model.predict(X_test)
y_hat = [0 if val < 0.5 else 1 for val in y_hat]
# Out:
# 45/45 [==============================] - 0s 3ms/step

# %%
accuracy_score(y_test, y_hat)
# Out:
# 0.7899219304471257

# %%
model.save('tfmodel')

# %%
del model

# %%
model = load_model('tfmodel')
